# %% [markdown]
# # Chronic Kidney Disease analysis

# %% [markdown]
# ## Data preparation

# %% [markdown]
# Get data from https://www.kaggle.com/datasets/rabieelkharoua/chronic-kidney-disease-dataset-analysis/data

# %%
# !wget https://www.kaggle.com/api/v1/datasets/download/rabieelkharoua/chronic-kidney-disease-dataset-analysis/Chronic_Kidney_Dsease_data.csv
# Out:
# --2024-11-02 07:10:56--  https://www.kaggle.com/api/v1/datasets/download/rabieelkharoua/chronic-kidney-disease-dataset-analysis/Chronic_Kidney_Dsease_data.csv
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com:443/kagglesdsdata/datasets/5187141/8658224/Chronic_Kidney_Dsease_data.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20241102%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20241102T071056Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
import pandas as pd

data_path = "/content/Chronic_Kidney_Dsease_data.csv"

df = pd.read_csv(data_path)

df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0          1   71       0          0                    0               2
# 1          2   34       0          0                    1               3
# 2          3   80       1          1                    0               1
# 3          4   40       0          2                    0               1
# 4          5   43       0          1                    1               2
#
#          BMI  Smoking  AlcoholConsumption  PhysicalActivity  ...   Itching  \
# 0  31.069414        1            5.128112          1.676220  ...  7.556302
# 1  29.692119        1           18.609552          8.377574  ...  6.836766
# 2  37.394822        1           11.882429          9.607401  ...  2.144722
# 3  31.329680        0           16.020165          0.408871  ...  7.077188
# 4  23.726311        0            7.944146          0.780319  ...  3.553118
#
# ...

# %% [markdown]
# ## EDA - Exploratory Data Analysis

# %%
df.describe().T
# Out:
#                                 count        mean         std         min  \
# PatientID                      1659.0  830.000000  479.056364    1.000000
# Age                            1659.0   54.441230   20.549757   20.000000
# Gender                         1659.0    0.515371    0.499914    0.000000
# Ethnicity                      1659.0    0.713080    1.000430    0.000000
# SocioeconomicStatus            1659.0    0.977697    0.776686    0.000000
# EducationLevel                 1659.0    1.693189    0.910611    0.000000
# BMI                            1659.0   27.620049    7.288670   15.033888
# Smoking                        1659.0    0.292948    0.455252    0.000000
# AlcoholConsumption             1659.0    9.969831    5.798787    0.021740
# PhysicalActivity               1659.0    5.024247    2.866274    0.001186
# DietQuality                    1659.0    5.028544    2.865777    0.002407
# SleepQuality                   1659.0    6.942324    1.704159    4.001053
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1659 entries, 0 to 1658
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   PatientID                      1659 non-null   int64
#  1   Age                            1659 non-null   int64
#  2   Gender                         1659 non-null   int64
#  3   Ethnicity                      1659 non-null   int64
#  4   SocioeconomicStatus            1659 non-null   int64
#  5   EducationLevel                 1659 non-null   int64
#  6   BMI                            1659 non-null   float64
#  7   Smoking                        1659 non-null   int64
#  8   AlcoholConsumption             1659 non-null   float64
#  9   PhysicalActivity               1659 non-null   float64
#  10  DietQuality                    1659 non-null   float64
#  11  SleepQuality                   1659 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'SocioeconomicStatus',
#        'EducationLevel', 'BMI', 'Smoking', 'AlcoholConsumption',
#        'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'FamilyHistoryKidneyDisease', 'FamilyHistoryHypertension',
#        'FamilyHistoryDiabetes', 'PreviousAcuteKidneyInjury',
#        'UrinaryTractInfections', 'SystolicBP', 'DiastolicBP',
#        'FastingBloodSugar', 'HbA1c', 'SerumCreatinine', 'BUNLevels', 'GFR',
#        'ProteinInUrine', 'ACR', 'SerumElectrolytesSodium',
#        'SerumElectrolytesPotassium', 'SerumElectrolytesCalcium',
#        'SerumElectrolytesPhosphorus', 'HemoglobinLevels', 'CholesterolTotal',
#        'CholesterolLDL', 'CholesterolHDL', 'CholesterolTriglycerides',
#        'ACEInhibitors', 'Diuretics', 'NSAIDsUse', 'Statins',
#        'AntidiabeticMedications', 'Edema', 'FatigueLevels', 'NauseaVomiting',
#        'MuscleCramps', 'Itching', 'QualityOfLifeScore', 'HeavyMetalsExposure',
# ...

# %%
df["DoctorInCharge"].unique()[:5]
# Out:
# array(['Confidential'], dtype=object)

# %%
# drop useless columns
df.drop(["DoctorInCharge", "PatientID"], axis=1, inplace=True)

# %%
# check for null values
df.isnull().sum()
# Out:
# Age                              0
# Gender                           0
# Ethnicity                        0
# SocioeconomicStatus              0
# EducationLevel                   0
# BMI                              0
# Smoking                          0
# AlcoholConsumption               0
# PhysicalActivity                 0
# DietQuality                      0
# SleepQuality                     0
# FamilyHistoryKidneyDisease       0
# FamilyHistoryHypertension        0
# FamilyHistoryDiabetes            0
# PreviousAcuteKidneyInjury        0
# UrinaryTractInfections           0
# SystolicBP                       0
# DiastolicBP                      0
# FastingBloodSugar                0
# HbA1c                            0
# SerumCreatinine                  0
# BUNLevels                        0
# GFR                              0
# ProteinInUrine                   0
# ACR                              0
# SerumElectrolytesSodium          0
# SerumElectrolytesPotassium       0
# ...

# %% [markdown]
# ### Correlation
#
# Show correlation between numerical columns

# %%
numerical_columns = df.select_dtypes(include=["int64", "float64"]).columns
correlations = df[numerical_columns].corr()

# %%
correlations
# Out:
#                                     Age    Gender  Ethnicity  \
# Age                            1.000000 -0.037765  -0.006307
# Gender                        -0.037765  1.000000   0.025707
# Ethnicity                     -0.006307  0.025707   1.000000
# SocioeconomicStatus            0.001448  0.004767  -0.047051
# EducationLevel                 0.008947 -0.022095   0.039696
# BMI                           -0.033202 -0.023381  -0.008506
# Smoking                        0.020215  0.004054   0.019127
# AlcoholConsumption            -0.006030 -0.020473  -0.033574
# PhysicalActivity               0.003485  0.014840  -0.057811
# DietQuality                    0.004062  0.011517  -0.012721
# SleepQuality                  -0.005151 -0.004312   0.029833
# FamilyHistoryKidneyDisease     0.014984  0.032584   0.010630
# FamilyHistoryHypertension     -0.008672 -0.007058  -0.021725
# FamilyHistoryDiabetes          0.001114  0.019137   0.007602
# ...

# %% [markdown]
# Correlation matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(correlations, cmap='coolwarm')
plt.title('Matrice di Correlazione')
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Histogram for BMI
plt.figure(figsize=(10, 5))
sns.histplot(df['BMI'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram for GFR
plt.figure(figsize=(10, 5))
sns.histplot(df['GFR'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of GFR')
plt.xlabel('GFR')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar plot for Gender
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Gender', palette='viridis')  # 'palette' specifies the color scheme
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Bar plot for diagnosis

plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Diagnosis', palette='viridis')  # 'palette' specifies the color scheme
plt.title('Distribution of positive - negative diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.show()

# %%
df.head().T

# %% [markdown]
# ### Feature importance

# %%
from sklearn.model_selection import train_test_split

df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.Diagnosis.values
y_val = df_val.Diagnosis.values
y_test = df_test.Diagnosis.values

# %%
del df_train["Diagnosis"]
del df_val["Diagnosis"]
del df_test["Diagnosis"]

# %% [markdown]
# Gender and Diagnosis.
#
# 0 = Male. 1 = Female

# %%
male_diagnosis = df_full_train[df_full_train.Gender == 0].Diagnosis.mean()
male_diagnosis

# %%
female_diagnosis = df_full_train[df_full_train.Gender == 1].Diagnosis.mean()
female_diagnosis

# %%
global_diagnosis = df_full_train.Diagnosis.mean()
global_diagnosis

# %% [markdown]
# Smoking and diagnosis

# %%
smoking_diagnosis = df_full_train[df_full_train.Smoking == 1].Diagnosis.mean()
smoking_diagnosis

# %%
no_smoking_diagnosis = df_full_train[df_full_train.Smoking == 0].Diagnosis.mean()
no_smoking_diagnosis

# %% [markdown]
# Water quality and diagnosis

# %%
water_0_diagnosis = df_full_train[df_full_train.WaterQuality == 0].Diagnosis.mean()
water_0_diagnosis

# %%
water_1_diagnosis = df_full_train[df_full_train.WaterQuality == 1].Diagnosis.mean()
water_1_diagnosis

# %% [markdown]
# ### Mutual information for feature importance

# %%
len(df_train), len(y_train)

# %%
from sklearn.metrics import mutual_info_score

df_columns = df_train.columns
def mutual_info_diagnosis_score(series):
  return mutual_info_score(series, y_train)

mis = df_train[df_columns].apply(mutual_info_diagnosis_score)
mis.sort_values(ascending=False)

# %%
import seaborn as sns

train_dataset = df_train.copy()
train_dataset.insert(0, "Diagnosis", y_train)
_ = sns.pairplot(
    train_dataset[
        ["Age", "AntidiabeticMedications", "FamilyHistoryKidneyDisease", "SystolicBP", "PhysicalActivity"]
    ],
    kind="reg",
    diag_kind="kde",
    plot_kws={"scatter_kws": {"alpha": 0.1}},
)

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### One-hot encoding

# %%
from sklearn.feature_extraction import DictVectorizer

dv = DictVectorizer(sparse=False)

train_dict = df_train.to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = df_val.to_dict(orient='records')
X_val = dv.transform(val_dict)

# %% [markdown]
# ### Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)

# %%
y_pred = model.predict_proba(X_val)[:, 1]
prediction_mean = y_pred.mean()
prediction_decision = (y_pred >= prediction_mean)

# %%
(y_val == prediction_decision).mean()

# %%
df_full_train[:1]

# %%
y_full_train = df_full_train.Diagnosis
del df_full_train['Diagnosis']

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
full_train_dict = df_full_train.to_dict(orient='records')
X_full_train = dv.fit_transform(full_train_dict)

test_dict = df_test.to_dict(orient='records')
X_test = dv.fit_transform(test_dict)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


def evaluate_logistic_regression(model, X_train, X_test, y_train, y_test):
  y_pred = model.predict(X_test)
  y_pred_prob = model.predict_proba(X_test)[:, 1]

  train_accuracy = accuracy_score(y_train, model.predict(X_train))
  test_accuracy = accuracy_score(y_test, y_pred)

  print("Model performance metrics:")
  print(f"Training Accuracy: {train_accuracy:.3f}")
  print(f"Testing Accuracy: {test_accuracy:.3f}")
  print("\nClassification Report:")
  print(classification_report(y_test, y_pred))

  # Plotting functions
  fig, axes = plt.subplots(2, 2, figsize=(15, 12))

  # Confusion matrix
  cm = confusion_matrix(y_test, y_pred)
  sns.heatmap(cm, annot=True, fmt='d', ax=axes[0,0])
  axes[0,0].set_title('Confusion Matrix')
  axes[0,0].set_ylabel('True Label')
  axes[0,0].set_xlabel('Predicted Label')

  # ROC Curve
  false_positives_rate, true_positives_rate, _ = roc_curve(y_test, y_pred_prob)
  roc_auc =auc(false_positives_rate, true_positives_rate)

  axes[0,1].plot(false_positives_rate, true_positives_rate, color='darkorange', lw=2,
                   label=f'ROC curve (AUC = {roc_auc:.2f})')
  axes[0,1].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
  axes[0,1].set_xlim([0.0, 1.0])
  axes[0,1].set_ylim([0.0, 1.05])
  axes[0,1].set_xlabel('False Positive Rate')
  axes[0,1].set_ylabel('True Positive Rate')
  axes[0,1].set_title('Receiver Operating Characteristic')
  axes[0,1].legend(loc="lower right")

  # Precision Recall Curve
  precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
  axes[1,0].plot(recall, precision, color='blue', lw=2)
  axes[1,0].set_xlabel('Recall')
  axes[1,0].set_ylabel('Precision')
  axes[1,0].set_title('Precision-Recall Curve')

  # Feature importance
  if hasattr(X_train, 'columns'):
    importance = pd.DataFrame({
        'feature': X_train.columns,
        'importance': abs(model.coef[0])
    }).sort_values('importance', ascending=True)

    importance.plot(x='importance', y='feature', kind='barh', ax=axes[1,1])
    axes[1,1].set_title('Feature Importance')
  else:
    feature_importance = abs(model.coef_[0])
    axes[1,1].barh(range(len(feature_importance)), feature_importance)
    axes[1,1].set_title('Feature Importance')
    axes[1,1].set_ylabel('Feature Index')

  plt.tight_layout()
  plt.show()

  return {
        'train_accuracy': train_accuracy,
        'test_accuracy': test_accuracy,
        'confusion_matrix': cm,
        'classification_report': classification_report(y_test, y_pred),
        'roc_auc': roc_auc
    }

# %%
evaluate_logistic_regression(model, X_full_train, X_test, y_full_train, y_test)

# %% [markdown]
# ### Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import roc_auc_score
from sklearn.tree import export_text

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)

# %%
y_pred = dt.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred)

# %%
y_pred = dt.predict_proba(X_train)[:, 1]
roc_auc_score(y_train, y_pred)

# %%
dt = DecisionTreeClassifier(max_depth=2)
dt.fit(X_train, y_train)

# %%
y_pred = dt.predict_proba(X_train)[:, 1]
auc = roc_auc_score(y_train, y_pred)
print('train:', auc)

# %%
y_pred = dt.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_pred)
print('val:', auc)

# %%
print(export_text(dt, feature_names=list(dv.get_feature_names_out())))

# %% [markdown]
# Parameters tuning for decision trees:
# - max_depth
# - min_samples_leaf

# %%
depths = [1, 2, 3, 4, 5, 6, 10, 15, 20, None]
for depth in depths:
  dt = DecisionTreeClassifier(max_depth=depth)
  dt.fit(X_train, y_train)

  y_pred = dt.predict_proba(X_val)[:, 1]
  auc = roc_auc_score(y_val, y_pred)

  print('%4s -> %.3f' % (depth, auc))

# %%
scores = []

for depth in [4, 5, 6]:
    for s in [1, 5, 10, 15, 20, 500, 100, 200]:
        dt = DecisionTreeClassifier(max_depth=depth, min_samples_leaf=s)
        dt.fit(X_full_train, y_full_train)

        y_pred = dt.predict_proba(X_test)[:, 1]
        auc = roc_auc_score(y_test, y_pred)

        scores.append((depth, s, auc))

# %%
columns = ['max_depth', 'min_samples_leaf', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)

# %%
df_scores_pivot = df_scores.pivot(index='min_samples_leaf', columns=['max_depth'], values=['auc'])
df_scores_pivot.round(3)

# %%
sns.heatmap(df_scores_pivot, annot=True, fmt=".3f")

# %%
dt = DecisionTreeClassifier(max_depth=4, min_samples_leaf=100)
dt.fit(X_full_train, y_full_train)

# %%
y_pred = dt.predict_proba(X_test)[:, 1]
auc = roc_auc_score(y_test, y_pred)
auc

# %%
print(export_text(dt, feature_names=list(dv.get_feature_names_out())))

# %% [markdown]
# ### Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# Find number of estimators:

# %%
scores = []

for n in range(10, 201, 10):
  rf = RandomForestClassifier(n_estimators=n, random_state=1)
  rf.fit(X_full_train, y_full_train)

  y_pred = rf.predict_proba(X_test)[:, 1]
  auc = roc_auc_score(y_test, y_pred)

  scores.append((n, auc))

# %%
df_scores = pd.DataFrame(scores, columns=['n_estimators', 'auc'])

# %%
plt.plot(df_scores.n_estimators, df_scores.auc)

# %% [markdown]
# Find max_depth and estimators:

# %%
scores = []

for d in [5, 10, 15]:
  for n in range(10, 201, 10):
    rf = RandomForestClassifier(n_estimators=n,
                                max_depth=d,
                                random_state=1)
    rf.fit(X_full_train, y_full_train)

    y_pred = rf.predict_proba(X_test)[:, 1]
    auc = roc_auc_score(y_test, y_pred)

    scores.append((d, n, auc))

# %%
columns = ['max_depth',"n_estimators", 'auc']
df_scores = pd.DataFrame(scores, columns=columns)

# %%
for d in [5, 10, 15]:
    df_subset = df_scores[df_scores.max_depth == d]

    plt.plot(df_subset.n_estimators, df_subset.auc,
             label='max_depth=%d' % d)

plt.legend()

# %%
# best max depth
max_depth = 15

# %% [markdown]
# Find best min samples leaf:

# %%
scores = []

for s in [1, 3, 5, 10, 50]:
    for n in range(10, 201, 10):
        rf = RandomForestClassifier(n_estimators=n,
                                    max_depth=max_depth,
                                    min_samples_leaf=s,
                                    random_state=1)
        rf.fit(X_full_train, y_full_train)

        y_pred = rf.predict_proba(X_test)[:, 1]
        auc = roc_auc_score(y_test, y_pred)

        scores.append((s, n, auc))

# %%
columns = ['min_samples_leaf', 'n_estimators', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)

# %%
colors = ['black', 'blue', 'orange', 'red', 'grey']
values = [1, 3, 5, 10, 50]

for s, col in zip(values, colors):
    df_subset = df_scores[df_scores.min_samples_leaf == s]

    plt.plot(df_subset.n_estimators, df_subset.auc,
             color=col,
             label='min_samples_leaf=%d' % s)

plt.legend()

# %%
min_samples_leaf = 50

# %%
rf = RandomForestClassifier(n_estimators=200,
                            max_depth=max_depth,
                            min_samples_leaf=min_samples_leaf,
                            random_state=1)
rf.fit(X_train, y_train)

# %% [markdown]
# ## Gradient boosting with XG Boost
#
# Tutorial: https://www.kaggle.com/code/yasinnsariyildiz/xgboost-tutorial

# %%
# !pip install xgboost

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt


# 1. Prima controlla la distribuzione delle classi
def check_class_distribution(y):
    unique, counts = np.unique(y, return_counts=True)
    dist = dict(zip(unique, counts))
    print("Distribuzione delle classi:")
    for k, v in dist.items():
        print(f"Classe {k}: {v} ({v/len(y)*100:.2f}%)")
    return dist

# 2. Configura XGBoost con parametri più appropriati
def create_balanced_xgboost():
    return XGBClassifier(
        n_estimators=100,  # Più alberi per un migliore apprendimento
        max_depth=3,       # Profondità moderata per evitare overfitting
        learning_rate=0.1, # Learning rate più basso per un apprendimento più graduale
        objective='binary:logistic',
        scale_pos_weight=1,  # Sarà aggiustato in base allo sbilanciamento
        random_state=42
    )

# 3. Training con monitoraggio
def train_and_evaluate_xgboost(X_train, X_val, X_test, y_train, y_val, y_test):
    # Controlla la distribuzione delle classi
    dist = check_class_distribution(y_train)
    if len(dist) == 2:
        neg, pos = dist[0], dist[1]
        scale_pos_weight = neg/pos
    else:
        scale_pos_weight = 1

    # Crea e configura il modello
    model = create_balanced_xgboost()
    model.set_params(scale_pos_weight=scale_pos_weight)

    # Parametri per la grid search
    param_grid = {
        'learning_rate': [0.01, 0.1],
        'max_depth': [3, 4, 5],
        'n_estimators': [50, 100, 200],
        'min_child_weight': [1, 3],
        'gamma': [0, 0.1],
        'subsample': [0.8, 1.0],
        'colsample_bytree': [0.8, 1.0]
    }

    # Training con early stopping
    eval_set = [(X_train, y_train), (X_val, y_val)]
    model.fit(
        X_train, y_train,
        eval_set=eval_set,
        # eval_metric=['logloss', 'error'],
        # early_stopping_rounds=10,
        verbose=True
    )

    # Grid Search
    grid_search = GridSearchCV(
        estimator=model,
        param_grid=param_grid,
        cv=5,
        scoring='f1',
        n_jobs=-1,
        verbose=1
    )

    # Fit del modello finale con i migliori parametri
    best_model = grid_search.fit(X_train, y_train).best_estimator_

    # Valutazione
    y_pred = best_model.predict(X_test)
    y_pred_proba = best_model.predict_proba(X_test)

    print("\nReport di classificazione:")
    print(classification_report(y_test, y_pred))

    print("\nMatrice di confusione:")
    print(confusion_matrix(y_test, y_pred))

    # Plot delle predizioni probabilistiche
    plt.figure(figsize=(10, 5))
    plt.hist(y_pred_proba[:, 1], bins=50)
    plt.title('Distribuzione delle Probabilità Predette')
    plt.xlabel('Probabilità di Classe 1')
    plt.ylabel('Frequenza')
    plt.show()

    return best_model

# 4. Funzione per verificare le predizioni
def verify_predictions(model, X):
    preds = model.predict(X)
    pred_probs = model.predict_proba(X)

    print("\nStatistiche delle predizioni:")
    print(f"Predizioni uniche: {np.unique(preds, return_counts=True)}")
    print("\nStatistiche delle probabilità:")
    print(f"Min prob classe 1: {pred_probs[:, 1].min():.3f}")
    print(f"Max prob classe 1: {pred_probs[:, 1].max():.3f}")
    print(f"Media prob classe 1: {pred_probs[:, 1].mean():.3f}")

    return preds, pred_probs

# Uso delle funzioni
def main():

    # Training e valutazione
    best_model = train_and_evaluate_xgboost(X_train, X_val, X_test, y_train, y_val, y_test)

    # Verifica delle predizioni
    verify_predictions(best_model, X_test)

    return best_model

# %%
# Crea e allena il modello
best_model = main()

# %% [markdown]
# #### Save and load best model with Pickle

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pickle


model_save_path = "/content/drive/MyDrive/Tutorial/Data talk club/ML Zoomcamp 2024/Projects/kidney-disease"
save_file_name = "xgbm_final_model.pkl"

# Save the model
with open(f'{model_save_path}/{save_file_name}', 'wb') as file:
    pickle.dump(best_model, file)

# Load the model (in a new session or later)
with open(f'{model_save_path}/{save_file_name}', 'rb') as file:
    loaded_model = pickle.load(file)

# %% [markdown]
# Generate random patients to use for prediction with the loaded model:

# %%
import numpy as np
import pandas as pd

def generate_random_patient():
    """
    Genera un dizionario con dati casuali ma realistici per un paziente.
    I valori sono basati sulle statistiche del dataset originale.
    """

    # Funzione helper per generare valori casuali entro limiti
    def random_value(mean, std, min_val, max_val):
        while True:
            value = np.random.normal(mean, std)
            if min_val <= value <= max_val:
                return value

    patient = {
        # Dati demografici
        'Age': int(random_value(54.44, 20.55, 20, 90)),
        'Gender': np.random.choice([0, 1], p=[0.48, 0.52]),
        'Ethnicity': np.random.choice([0, 1, 2, 3], p=[0.5, 0.3, 0.1, 0.1]),
        'SocioeconomicStatus': np.random.choice([0, 1, 2], p=[0.3, 0.4, 0.3]),
        'EducationLevel': np.random.choice([0, 1, 2, 3], p=[0.1, 0.3, 0.4, 0.2]),

        # Misure fisiche e stile di vita
        'BMI': random_value(27.62, 7.29, 15.03, 40),
        'Smoking': np.random.choice([0, 1], p=[0.71, 0.29]),
        'AlcoholConsumption': random_value(9.97, 5.80, 0.02, 20),
        'PhysicalActivity': random_value(5.02, 2.87, 0, 10),
        'DietQuality': random_value(5.03, 2.87, 0, 10),
        'SleepQuality': random_value(6.94, 1.70, 4, 10),

        # Storia familiare
        'FamilyHistoryKidneyDisease': np.random.choice([0, 1], p=[0.86, 0.14]),
        'FamilyHistoryHypertension': np.random.choice([0, 1], p=[0.70, 0.30]),
        'FamilyHistoryDiabetes': np.random.choice([0, 1], p=[0.74, 0.26]),

        # Storia clinica
        'PreviousAcuteKidneyInjury': np.random.choice([0, 1], p=[0.89, 0.11]),
        'UrinaryTractInfections': np.random.choice([0, 1], p=[0.79, 0.21]),

        # Parametri vitali
        'SystolicBP': random_value(134.39, 25.77, 90, 179),
        'DiastolicBP': random_value(89.31, 17.35, 60, 119),

        # Esami del sangue
        'FastingBloodSugar': random_value(132.53, 36.56, 70.04, 200),
        'HbA1c': random_value(6.98, 1.73, 4, 10),
        'SerumCreatinine': random_value(2.75, 1.32, 0.50, 5),
        'BUNLevels': random_value(27.58, 12.81, 5, 50),
        'GFR': random_value(66.83, 30.05, 15.11, 120),

        # Test urine
        'ProteinInUrine': random_value(2.49, 1.45, 0, 5),
        'ACR': random_value(149.88, 86.85, 0.18, 300),

        # Elettroliti
        'SerumElectrolytesSodium': random_value(139.97, 2.91, 135, 145),
        'SerumElectrolytesPotassium': random_value(4.51, 0.58, 3.5, 5.5),
        'SerumElectrolytesCalcium': random_value(9.49, 0.57, 8.5, 10.5),
        'SerumElectrolytesPhosphorus': random_value(3.51, 0.58, 2.5, 4.5),

        # Altri valori ematici
        'HemoglobinLevels': random_value(13.93, 2.34, 10, 18),
        'CholesterolTotal': random_value(224.25, 43.67, 150, 300),
        'CholesterolLDL': random_value(125.04, 42.65, 50, 200),
        'CholesterolHDL': random_value(60.75, 23.17, 20, 100),
        'CholesterolTriglycerides': random_value(224.80, 100.32, 50, 400),

        # Medicinali
        'ACEInhibitors': np.random.choice([0, 1], p=[0.70, 0.30]),
        'Diuretics': np.random.choice([0, 1], p=[0.68, 0.32]),
        'NSAIDsUse': random_value(5.01, 2.87, 0, 10),
        'Statins': np.random.choice([0, 1], p=[0.62, 0.38]),
        'AntidiabeticMedications': np.random.choice([0, 1], p=[0.80, 0.20]),

        # Sintomi
        'Edema': np.random.choice([0, 1], p=[0.80, 0.20]),
        'FatigueLevels': random_value(5.02, 2.90, 0, 10),
        'NauseaVomiting': random_value(3.48, 1.99, 0, 7),
        'MuscleCramps': random_value(3.53, 2.03, 0, 7),
        'Itching': random_value(5.05, 2.88, 0, 10),

        # Qualità della vita e fattori ambientali
        'QualityOfLifeScore': random_value(49.73, 27.83, 0, 100),
        'HeavyMetalsExposure': np.random.choice([0, 1], p=[0.96, 0.04]),
        'OccupationalExposureChemicals': np.random.choice([0, 1], p=[0.90, 0.10]),
        'WaterQuality': np.random.choice([0, 1], p=[0.80, 0.20]),

        # Gestione della salute
        'MedicalCheckupsFrequency': random_value(2.00, 1.14, 0, 4),
        'MedicationAdherence': random_value(4.95, 2.87, 0, 10),
        'HealthLiteracy': random_value(5.14, 2.90, 0, 10)
    }

    # Arrotonda i valori numerici a 2 decimali
    for key, value in patient.items():
        if isinstance(value, float):
            patient[key] = round(value, 2)

    return patient

# Funzione per generare multipli pazienti
def generate_multiple_patients(n=1):
    """
    Genera n dizionari di pazienti casuali.

    Args:
        n (int): Numero di pazienti da generare

    Returns:
        list: Lista di dizionari, uno per ogni paziente
    """
    return [generate_random_patient() for _ in range(n)]

# %%
paziente = generate_random_patient()
paziente

# %%
prediction = xgbm_final.predict(pd.DataFrame([paziente]))
prediction

# %%
pazienti = generate_multiple_patients(n=5)
predictions = xgbm_final.predict(pd.DataFrame(pazienti))
predictions

# %%
# Per fare predizioni su nuovi dati
pazienti = generate_multiple_patients(n=50)
predictions = loaded_model.predict(pd.DataFrame(pazienti))
predictions

# %%
prediction = loaded_model.predict(pd.DataFrame([generate_random_patient()]))
prediction
